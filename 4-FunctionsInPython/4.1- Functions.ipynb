# %% [markdown]
# ## Introduction To Functions
#
#
# #### Defination
#
# A Function is a block of  code that performs a specific task. Functions help in organizing code , reusing code , and improving readability.

# %%
### Syntax
def function_name(parameters):
    "Docstring"
    #Function Body
    return expression

# %%
### Why Functions?
num = 24
if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# The number is Even

# %%
def even_or_odd(num):
    """This Function finds even or odd"""
    if num % 2 == 0:
        print("The number is Even")
    else:
        print("The number is odd")

# %%
### Call this function
even_or_odd(24)
# Out:
# The number is Even

# %%
## Function with multiple parameters

def add(a,b):
    """Adding two variables"""
    return a + b
result = add(2, 6)
print(result)
# Out:
# 8

# %%
## Default Parameters

def greet(name = "Guest"):
    print(f"Hellooo {name}...Welcome to the paradise!")
greet("Ammu")
# Out:
# Hellooo Ammu...Welcome to the paradise!

# %%
## Variable Length Arguments
## Positional And Keywords Arguments

def print_numbers(*ammu):
    for number in ammu:
        print(number)
print_numbers(1, 2, 3, 4, 5, 6, 7, 8, "ammu")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# ammu

# %%
##Positional Arguments
def print_numbers(*args):
    for number in args:
        print(number)
print_numbers(1, 2, 3, 4, 5, 6, 7, 8, "ammu")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# ammu

# %%
## Keywords Argument
def print_details(**kwargs):
    for key, value in kwargs.items():
        print(f"{key} : {value}")
print_details(name = "Ammu" , age = "20" , country = "India")
# Out:
# name : Ammu
# age : 20
# country : India

# %%
def print_details(*args ,**kwargs):
    for val in args:
        print(f"Positional argument : {val}")
        
    for key, value in kwargs.items():
        print(f"{key} : {value}")
        
print_details(1, 2, 3, 4, 5, "Ammu" , name = "Ammu" , age = "20" , country = "India")
# Out:
# Positional argument : 1
# Positional argument : 2
# Positional argument : 3
# Positional argument : 4
# Positional argument : 5
# Positional argument : Ammu
# name : Ammu
# age : 20
# country : India

# %%
### Return Statements
def multiply(a, b):
    return a * b
multiply(2, 4)
# Out:
# 8

# %%
### Return Multiple Parametrs
def multiply(a, b):
    return a * b , a
multiply(2, 4)
# Out:
# (8, 2)
